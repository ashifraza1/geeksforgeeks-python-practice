# %%
#WAP to find the maximum number in a list
n=int(input("enter a number"))
list=[]
for i in range(n):
  num=int(input("enter a number"))
  list.append(num)
print(max(list))
# Out:
# enter a number3
# enter a number6
# enter a number9
# enter a number10
# 10
